# %% [markdown]
# <a href="https://colab.research.google.com/github/ankitc21/finance_causal_rl/blob/main/notebooks/01_environment_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install torch torchvision torchaudio
# !pip install dowhy
# !pip install networkx
# !pip install stable-baselines3[extra]
# !pip install fredapi
# !pip install kaggle
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 403.1/403.1 kB 10.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 191.8/191.8 kB 14.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 36.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 52.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.16.3
#     Uninstalling scipy-1.16.3:
#       Successfully uninstalled scipy-1.16.3
#   Attempting uninstall: cvxpy
#     Found existing installation: cvxpy 1.6.7
#     Uninstalling cvxpy-1.6.7:
#       Successfully uninstalled cvxpy-1.6.7
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.0/188.0 kB 4.6 MB/s eta 0:00:00
# ...

# %%
'''from google.colab import drive
drive.mount('/content/drive')
'''
# Out:
# Mounted at /content/drive

# %%
'''import os

BASE_PATH = "/content/drive/MyDrive/Finance_Causal_RL"

folders = [
    "data/raw",
    "data/processed",
    "models",
    "experiments",
    "logs"
]

for f in folders:
    os.makedirs(f"{BASE_PATH}/{f}", exist_ok=True)

print("Research directory created successfully.")'''
# Out:
# Research directory created successfully.

# %%
import torch
print("CUDA Available:", torch.cuda.is_available())
# Out:
# CUDA Available: True

# %%
# !git clone https://github.com/ankitc21/finance_causal_rl.git
# Out:
# Cloning into 'finance_causal_rl'...
# remote: Enumerating objects: 28, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 28 (delta 3), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (28/28), 8.58 KiB | 2.86 MiB/s, done.
# Resolving deltas: 100% (3/3), done.

# %%
import sys
sys.path.append('/content/finance_causal_rl')

# %%
import os
print(os.listdir('/content/finance_causal_rl'))
# Out:
# ['data', 'experiments', '.git', 'notebooks', 'models']
